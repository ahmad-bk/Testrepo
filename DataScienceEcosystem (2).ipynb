# %% [markdown]
# #Data Science Tools and Ecosystem

# %% [markdown]
# In this notebooks, Data Science Tools and Ecosystem are summarized

# %% [markdown]
# ***Objectives***
# - List common Libraries used by Data Scientists
# - List some popular languages used by Data Sscientists
# - Run some arithmetic expression in Python
# - Create a table of data science tools

# %% [markdown]
# Some of the popular languages that Data Scientists use are:

# %% [markdown]
# 1. Rstudio
# 2. Java
# 3. Python

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. NumPy
# 2. Pandas
# 3. Seaborn
# 4. Scikit-learn

# %% [markdown]
# |Data Science Tools|
# |------------------|
#
# | My SQL | Hue | Rstudio |
# |--------|-----|---------|

# %% [markdown]
# ### Below are few examples of evaluating arithmentic expressions in Python

# %%
#This is a simple arithmetic expression to multiply then add integers.
(3*4)+5
# Out:
# 17

# %%
#This will convert minutes to hours by dividing by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author.
# Ahmad Usman
